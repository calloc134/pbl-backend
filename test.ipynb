# %%
import requests
import random
import json
import pprint

# APIのベースURL
base_url = ""

# 生徒を追加する
def add_student(name, student_id, device_id):
    url = f"{base_url}/students"
    payload = {
        "name": name,
        "student_id": student_id,
        "device_id": device_id
    }
    response = requests.post(url, data=json.dumps(payload))
    return response.json()

# 先生を追加する
def add_teacher(name, teacher_id):
    url = f"{base_url}/teachers"
    payload = {
        "name": name,
        "teacher_id": teacher_id
    }
    response = requests.post(url, data=json.dumps(payload))
    return response.json()

# すべての生徒を取得する
def get_all_students():
    url = f"{base_url}/students"
    response = requests.get(url)
    return response.json()

# すべての先生を取得する
def get_all_teachers():
    url = f"{base_url}/teachers"
    response = requests.get(url)
    return response.json()

# 一人の生徒を取得する
def get_student(student_uuid):
    url = f"{base_url}/students/{student_uuid}"
    response = requests.get(url)
    return response.json()

# 一人の先生を取得する
def get_teacher(teacher_uuid):
    url = f"{base_url}/teachers/{teacher_uuid}"
    response = requests.get(url)
    return response.json()

# 授業を追加する
def add_lesson(name, teacher_uuid):
    url = f"{base_url}/lessons"
    payload = {
        "name": name,
        "teacher_uuid": teacher_uuid
    }
    response = requests.post(url, data=json.dumps(payload))
    return response.json()

# 授業の詳細を取得する
def get_lesson_details(lesson_uuid):
    url = f"{base_url}/lessons/{lesson_uuid}"
    response = requests.get(url)
    return response.json()

# 生徒が履修している授業の一覧を取得する
def get_student_join_lessons(student_uuid):
    url = f"{base_url}/students/{student_uuid}/join-lessons"
    response = requests.get(url)
    return response.json()

# 生徒の出席状況を取得する
def get_student_attendances(student_uuid):
    url = f"{base_url}/students/{student_uuid}/attendances"
    response = requests.get(url)
    return response.json()

# 特定の授業の出席状況を取得する
def get_lesson_attendances(lesson_uuid):
    url = f"{base_url}/lessons/{lesson_uuid}/attendances"
    response = requests.get(url)
    return response.json()

# 生徒が履修を登録する
def join_lesson(student_uuid, lesson_uuid):
    url = f"{base_url}/join-lessons"
    payload = {
        "student_uuid": student_uuid,
        "lesson_uuid": lesson_uuid
    }
    response = requests.post(url, data=json.dumps(payload))
    return response.json()

# 授業を開始する
def start_lesson(lesson_uuid):
    url = f"{base_url}/lessons/{lesson_uuid}/start"
    response = requests.post(url)
    return response.json()

# 出席リクエストを受信する
def post_attendances(device_ids):
    url = f"{base_url}/attendances-endpoint"
    payload = {
        "device_ids": device_ids
    }
    response = requests.post(url, data=json.dumps(payload))
    return response.json()

# 授業を終了する
def end_lesson(lesson_uuid):
    url = f"{base_url}/lessons/{lesson_uuid}/end"
    response = requests.post(url)
    return response.json()

# 名前ジェネレータ
def gen_name():
    return "{} {}".format(
        random.choice(["池下", "石井", "岩崎", "大橋", "大西", "大野", "小林", "小松", "小山", "小池", "斉藤", "佐々木", "佐藤", "椎名", "鈴木", "高橋", "田中", "中村", "中島", "中野", "西村", "西田", "松本", "松山", "松岡", "松尾", "松田", "松井", "山口", "山田", "山本", "吉田", "和田"]),
        random.choice(["太郎", "祐介", "健太", "秀樹", "雅人"])
    )
    



# 今回作成する生徒と先生、授業の情報
# 生徒

print("生徒を作成します")
print("五人の生徒を作成します")
students = []
for i in range(5):
    student_id = random.randint(15000000, 16000000)
    student_name = gen_name()
    student_device_id = "{:012x}".format(random.randint(0, 2**48-1)) + "0000"
    students.append({
        "student_id": student_id, # これはあとで使うので、ここに入れておく
        "student_name": student_name,
        "student_device_id": student_device_id
    })
    print(f"{student_name}さんを作成しました")

print("先生を作成します")
print("二人の先生を作成します")
teachers = []
for i in range(2):
    teacher_name = gen_name()
    teacher_id = random.randint(15000000, 16000000)
    teachers.append({
        "teacher_id": teacher_id, # これはあとで使うので、ここに入れておく
        "teacher_name": teacher_name,
    })
    print(f"{teacher_name}先生を作成しました")

print("授業を作成します")
print("三つの授業を作成します")
print("授業は一人の先生が2つ、もう一人が1つ担当します")
lessons = []

lessons.append({
    "lesson_name": "数学",
})

lessons.append({
    "lesson_name": "英語",
})

lessons.append({
    "lesson_name": "理科",  
})



print("では、登録を開始します")

print("生徒を登録します")

for student in students:
    result = add_student(student["student_name"], student["student_id"], student["student_device_id"])
    student["student_uuid"] = result["student_uuid"]
    pprint.pprint(result)
    print(f"{student['student_name']}さんを登録しました")

print("先生を登録します")

for teacher in teachers:
    result = add_teacher(teacher["teacher_name"], teacher["teacher_id"])
    teacher["teacher_uuid"] = result["teacher_uuid"]
    pprint.pprint(result)
    print(f"{teacher['teacher_name']}先生を登録しました")

print("授業を登録します")

print("数学を登録します")
print(f"数学は{teachers[0]['teacher_name']}先生が担当します")
result = add_lesson(lessons[0]["lesson_name"], teachers[0]["teacher_uuid"])
lessons[0]["lesson_uuid"] = result["lesson_uuid"]
pprint.pprint(result)

print("英語を登録します")
print(f"英語は{teachers[0]['teacher_name']}先生が担当します")
result = add_lesson(lessons[1]["lesson_name"], teachers[0]["teacher_uuid"])
lessons[1]["lesson_uuid"] = result["lesson_uuid"]
pprint.pprint(result)

print("理科を登録します")
print(f"理科は{teachers[1]['teacher_name']}先生が担当します")
result = add_lesson(lessons[2]["lesson_name"], teachers[1]["teacher_uuid"])
lessons[2]["lesson_uuid"] = result["lesson_uuid"]
pprint.pprint(result)


print("すべての生徒を取得します")
pprint.pprint(get_all_students())

print("すべての先生を取得します")
pprint.pprint(get_all_teachers())

print("一人の生徒を取得します")
pprint.pprint(get_student(students[0]["student_uuid"]))

print("一人の先生を取得します")
pprint.pprint(get_teacher(teachers[0]["teacher_uuid"]))

print("授業の詳細を取得します")
pprint.pprint(get_lesson_details(lessons[0]["lesson_uuid"]))

print("では、現在の生徒の履修状況を確認します")
for student in students:
    print(f"{student['student_name']}さんの履修状況")
    pprint.pprint(get_student_join_lessons(student["student_uuid"]))
    print("")

print("生徒が履修を登録します")

print(f"{students[0]['student_name']}さんが数学を履修します")
result = join_lesson(students[0]["student_uuid"], lessons[0]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[0]['student_name']}さんが英語を履修します")
result = join_lesson(students[0]["student_uuid"], lessons[1]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[0]['student_name']}さんが理科を履修します")
result = join_lesson(students[0]["student_uuid"], lessons[2]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[1]['student_name']}さんが数学を履修します")
result = join_lesson(students[1]["student_uuid"], lessons[0]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[1]['student_name']}さんが理科を履修します")
result = join_lesson(students[1]["student_uuid"], lessons[2]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[2]['student_name']}さんが英語を履修します")
result = join_lesson(students[2]["student_uuid"], lessons[1]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[2]['student_name']}さんが理科を履修します")
result = join_lesson(students[2]["student_uuid"], lessons[2]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[3]['student_name']}さんが数学を履修します")
result = join_lesson(students[3]["student_uuid"], lessons[0]["lesson_uuid"])
pprint.pprint(result)

print(f"{students[3]['student_name']}さんが英語を履修します")
result = join_lesson(students[3]["student_uuid"], lessons[1]["lesson_uuid"])
pprint.pprint(result)

print("では、現在の生徒の履修状況を確認します")
for student in students:
    print(f"{student['student_name']}さんの履修状況")
    pprint.pprint(get_student_join_lessons(student["student_uuid"]))
    print("")

print("では、現在の生徒の出席状況を確認します")
for student in students:
    print(f"{student['student_name']}さんの出席状況")
    pprint.pprint(get_student_attendances(student["student_uuid"]))
    print("")


print("授業が開始します")
print("数学が開始します")
result = start_lesson(lessons[0]["lesson_uuid"])
pprint.pprint(result)

print("Aさんが出席します")
result = post_attendances([students[0]["student_device_id"]])
pprint.pprint(result)

print("Bさんが出席します")
result = post_attendances([students[1]["student_device_id"]])
pprint.pprint(result)

print("Dさんは出席しません")

print("授業が終了します")

result = end_lesson(lessons[0]["lesson_uuid"])

print("では、現在の生徒の出席状況を確認します")
for student in students:
    print(f"{student['student_name']}さんの出席状況")
    pprint.pprint(get_student_attendances(student["student_uuid"]))
    print("")

print("では、現在の授業の出席状況を確認します")
for lesson in lessons:
    print(f"{lesson['lesson_name']}の出席状況")
    pprint.pprint(get_lesson_attendances(lesson["lesson_uuid"]))
    print("")
# Out:
# 生徒を作成します
# 五人の生徒を作成します
# 西田 太郎さんを作成しました
# 松尾 雅人さんを作成しました
# 山田 雅人さんを作成しました
# 中島 秀樹さんを作成しました
# 小林 雅人さんを作成しました
# 先生を作成します
# 二人の先生を作成します
# 岩崎 太郎先生を作成しました
# 石井 健太先生を作成しました
# 授業を作成します
# 三つの授業を作成します
# 授業は一人の先生が2つ、もう一人が1つ担当します
# では、登録を開始します
# 生徒を登録します
# {'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'}
# 西田 太郎さんを登録しました
# {'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'}
# 松尾 雅人さんを登録しました
# {'student_uuid': '01HGWJRBK3YD2C962EZ5893APC'}
# 山田 雅人さんを登録しました
# {'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'}
# 中島 秀樹さんを登録しました
# {'student_uuid': '01HGWJRC17K5YAWG31K4T87AP7'}
# 小林 雅人さんを登録しました
# 先生を登録します
# {'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'}
# 岩崎 太郎先生を登録しました
# {'teacher_uuid': '01HGWJRCG29TMYVY53YACKJBPM'}
# 石井 健太先生を登録しました
# 授業を登録します
# 数学を登録します
# 数学は岩崎 太郎先生が担当します
# {'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85'}
# 英語を登録します
# 英語は岩崎 太郎先生が担当します
# {'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0'}
# 理科を登録します
# 理科は石井 健太先生が担当します
# {'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG'}
# すべての生徒を取得します
# [{'device_id': '10ff924878b00000',
#   'name': 'あきな',
#   'student_id': 221205098,
#   'student_uuid': '01HGWGPBJWET4RBD0TRGS1WPJJ'},
#  {'device_id': 'eb9b155f19510000',
#   'name': 'あきら',
#   'student_id': 221205038,
#   'student_uuid': '01HGWGT5PF6E2GWQXXWFDNSNG0'},
#  {'device_id': '029932ebfdf00000',
#   'name': '大橋',
#   'student_id': 221205174,
#   'student_uuid': '01HGWHQKYZNHHARGRPWDCHW796'},
#  {'device_id': 'b7080ed9e4d30000',
#   'name': '松岡 六',
#   'student_id': 221205019,
#   'student_uuid': '01HGWHWHD6P2J2S9M9064JX49G'},
#  {'device_id': 'e7201dccb0c70000',
#   'name': '和田 雅人',
#   'student_id': 221205087,
#   'student_uuid': '01HGWHZ8QKJ3B2WWHXFWCPS6EZ'},
#  {'device_id': '38b3bbd158d80000',
#   'name': '小池 太郎',
#   'student_id': 221205159,
#   'student_uuid': '01HGWJ1CQPV6AX6HTEVX7BW1EB'},
#  {'device_id': 'cc460fc4196f0000',
#   'name': '小松 太郎',
#   'student_id': 221205196,
#   'student_uuid': '01HGWJ2A80TENV8K9T4YMXQ1NE'},
#  {'device_id': '8c7232fa6e740000',
#   'name': '大野 太郎',
#   'student_id': 221205067,
#   'student_uuid': '01HGWJ2EQSR9Z9JY65AXTZV22N'},
#  {'device_id': '436692aaee6d0000',
#   'name': '松山 雅人',
#   'student_id': 221205097341,
#   'student_uuid': '01HGWJ3RTD8R4H9M2EW0DZVK5X'},
#  {'device_id': '6c0c41b1465a0000',
#   'name': '椎名 健太',
#   'student_id': 221205089181,
#   'student_uuid': '01HGWJ4YWZ287V8BJWTJ5NXSA5'},
#  {'device_id': 'bd9e64a692270000',
#   'name': '大橋 雅人',
#   'student_id': 221205134736,
#   'student_uuid': '01HGWJ5C93JVK14HZVFRF5JRZM'},
#  {'device_id': '50b2bbc466780000',
#   'name': '小松 健太',
#   'student_id': 221205134008,
#   'student_uuid': '01HGWJ5JNXCAGA1P1ZF5Z5BJEW'},
#  {'device_id': 'b03bedddb54e0000',
#   'name': '鈴木 雅人',
#   'student_id': 15641628,
#   'student_uuid': '01HGWJ7BRNPDVQNAS8DCCW8CWT'},
#  {'device_id': '5b21352493160000',
#   'name': '大橋 健太',
#   'student_id': 15197718,
#   'student_uuid': '01HGWJC0541369RQBTASRH2Z6E'},
#  {'device_id': '98aa3e504c1b0000',
#   'name': '中村 太郎',
#   'student_id': 15189646,
#   'student_uuid': '01HGWJD0PXT3SABB8EZPQ9112A'},
#  {'device_id': 'e06dee5e7d3c0000',
#   'name': '松井 秀樹',
#   'student_id': 15676920,
#   'student_uuid': '01HGWJD0ZQRFADGKQ6DM0ZAH6D'},
#  {'device_id': '9cffb10e13e10000',
#   'name': '山口 秀樹',
#   'student_id': 15728446,
#   'student_uuid': '01HGWJD15CAGBRQCX0D2AC4HMA'},
#  {'device_id': 'b8929e2fc4040000',
#   'name': '椎名 太郎',
#   'student_id': 15740999,
#   'student_uuid': '01HGWJD1CP9KSYTW98JTPER8V6'},
#  {'device_id': 'b4b4eb1484980000',
#   'name': '山田 雅人',
#   'student_id': 15084848,
#   'student_uuid': '01HGWJD1PDFSZTJVS65NYVXAK2'},
#  {'device_id': '3e616e13dab90000',
#   'name': '松山 雅人',
#   'student_id': 15176667,
#   'student_uuid': '01HGWJGMWV2Q0SRC2M5N5J5V6X'},
#  {'device_id': '16182881b6e00000',
#   'name': '松山 祐介',
#   'student_id': 15691092,
#   'student_uuid': '01HGWJGN8Y86Y1HTJXXXFH0VRQ'},
#  {'device_id': '29911109de9b0000',
#   'name': '和田 健太',
#   'student_id': 15582783,
#   'student_uuid': '01HGWJGNEJMBAWR6ZPGT9PZ0QP'},
#  {'device_id': '291647eb01800000',
#   'name': '中野 祐介',
#   'student_id': 15009554,
#   'student_uuid': '01HGWJGNK9087Y960TSNHRR1WA'},
#  {'device_id': 'a5c68cc1b5290000',
#   'name': '松井 太郎',
#   'student_id': 15273021,
#   'student_uuid': '01HGWJGNQKMERY9YEVG2568P93'},
#  {'device_id': 'a472c6d65c780000',
#   'name': '松山 秀樹',
#   'student_id': 15308424,
#   'student_uuid': '01HGWJJTBZSBHYDSEJ23WYG846'},
#  {'device_id': 'b2011f74e4740000',
#   'name': '中村 雅人',
#   'student_id': 15213293,
#   'student_uuid': '01HGWJJTX6R8SVZM95FYNE8Z62'},
#  {'device_id': 'ab03240877200000',
#   'name': '鈴木 太郎',
#   'student_id': 15423889,
#   'student_uuid': '01HGWJJVGDZYG9R0KS9NAR75AS'},
#  {'device_id': 'fc93a00291f30000',
#   'name': '山本 祐介',
#   'student_id': 15140422,
#   'student_uuid': '01HGWJJW0CQKM9HYD277FMC159'},
#  {'device_id': '8ec4d127b3bb0000',
#   'name': '大野 太郎',
#   'student_id': 15631092,
#   'student_uuid': '01HGWJJWG3HDXEXZDQNEE63PZJ'},
#  {'device_id': 'ffd088a00d160000',
#   'name': '中野 健太',
#   'student_id': 15067657,
#   'student_uuid': '01HGWJRAH251KNKHEBAVBJ9QQ1'},
#  {'device_id': '390bade45e3e0000',
#   'name': '西田 太郎',
#   'student_id': 15476439,
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'},
#  {'device_id': '5c0f95d9259e0000',
#   'name': '中村 太郎',
#   'student_id': 15098833,
#   'student_uuid': '01HGWJRB22JF7M32B5FKZ5JJ9F'},
#  {'device_id': 'd0f6b8aab4ca0000',
#   'name': '松尾 雅人',
#   'student_id': 15616419,
#   'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'},
#  {'device_id': '9bd80fe97db10000',
#   'name': '山田 雅人',
#   'student_id': 15238808,
#   'student_uuid': '01HGWJRBK3YD2C962EZ5893APC'},
#  {'device_id': '76eb19bceb650000',
#   'name': '鈴木 雅人',
#   'student_id': 15742533,
#   'student_uuid': '01HGWJRBJRKPSNABN2C145GXCJ'},
#  {'device_id': 'cbf9e16386090000',
#   'name': '中島 秀樹',
#   'student_id': 15650110,
#   'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'},
#  {'device_id': '7ed16b2a992c0000',
#   'name': '小林 雅人',
#   'student_id': 15261246,
#   'student_uuid': '01HGWJRC17K5YAWG31K4T87AP7'},
#  {'device_id': 'cac25e8e80250000',
#   'name': '小林 雅人',
#   'student_id': 15493186,
#   'student_uuid': '01HGWJRC4DVQXWWP7NG8MG2VAN'},
#  {'device_id': '1fc09d47473c0000',
#   'name': '小池 雅人',
#   'student_id': 15055324,
#   'student_uuid': '01HGWJRCNSQR4KFVYR8SY9RE0P'}]
# すべての先生を取得します
# [{'name': '小池',
#   'teacher_id': 15824,
#   'teacher_uuid': '01HGWGPBVVYJ1FB54C4PF55PWD'},
#  {'name': '小松',
#   'teacher_id': 15552,
#   'teacher_uuid': '01HGWGT6027VVJ9CKW3DYZS8GJ'},
#  {'name': '大野 健太',
#   'teacher_id': 15076474,
#   'teacher_uuid': '01HGWJD1WKBVJACXN5ECX7Y5P2'},
#  {'name': '岩崎 秀樹',
#   'teacher_id': 15926312,
#   'teacher_uuid': '01HGWJD23NES46QC2J1S5YVSY1'},
#  {'name': '中島 太郎',
#   'teacher_id': 15738618,
#   'teacher_uuid': '01HGWJGNVX92R4748YF6XRKHRZ'},
#  {'name': '佐々木 健太',
#   'teacher_id': 15259091,
#   'teacher_uuid': '01HGWJGP0D8S3DMEYTE2A9XTD4'},
#  {'name': '松本 健太',
#   'teacher_id': 15676143,
#   'teacher_uuid': '01HGWJJWZP8J9GKT1WHJK31YZ9'},
#  {'name': '吉田 太郎',
#   'teacher_id': 15730997,
#   'teacher_uuid': '01HGWJJXEV3C85KAC9CX88NJ4Z'},
#  {'name': '岩崎 太郎',
#   'teacher_id': 15860572,
#   'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#  {'name': '石井 健太',
#   'teacher_id': 15909832,
#   'teacher_uuid': '01HGWJRCG29TMYVY53YACKJBPM'},
#  {'name': '中村 太郎',
#   'teacher_id': 15425503,
#   'teacher_uuid': '01HGWJRD6WVSYN1HVR4TCN5ZHR'}]
# 一人の生徒を取得します
# {'device_id': '390bade45e3e0000',
#  'name': '西田 太郎',
#  'student_id': 15476439,
#  'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'}
# 一人の先生を取得します
# {'name': '岩崎 太郎',
#  'teacher_id': 15860572,
#  'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'}
# 授業の詳細を取得します
# {'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#  'name': '数学',
#  'status': 0,
#  'teacher_lessons': {'name': '岩崎 太郎',
#                      'teacher_id': 15860572,
#                      'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#  'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'}
# では、現在の生徒の履修状況を確認します
# 西田 太郎さんの履修状況
# []
#
# 松尾 雅人さんの履修状況
# []
#
# 山田 雅人さんの履修状況
# []
#
# 中島 秀樹さんの履修状況
# []
#
# 小林 雅人さんの履修状況
# []
#
# 生徒が履修を登録します
# 西田 太郎さんが数学を履修します
# {'join_lesson_uuid': '01HGWJRF730CW9SADHXHH8MHSN'}
# 西田 太郎さんが英語を履修します
# {'join_lesson_uuid': '01HGWJRFEG7A8QNME74MH3KTPZ'}
# 西田 太郎さんが理科を履修します
# {'join_lesson_uuid': '01HGWJRFN9DSYDYYE7WRWZPXG8'}
# 松尾 雅人さんが数学を履修します
# {'join_lesson_uuid': '01HGWJRFXH347Y217QHHCKJMG7'}
# 松尾 雅人さんが理科を履修します
# {'join_lesson_uuid': '01HGWJRG83SAFQ8DXZXYH7HC8M'}
# 山田 雅人さんが英語を履修します
# {'join_lesson_uuid': '01HGWJRGJ40XBWJ2GR12587JET'}
# 山田 雅人さんが理科を履修します
# {'join_lesson_uuid': '01HGWJRGVHP32PKWJ7RQXF9GF6'}
# 中島 秀樹さんが数学を履修します
# {'join_lesson_uuid': '01HGWJRH52THNQVMJCRHTNFVS2'}
# 中島 秀樹さんが英語を履修します
# {'join_lesson_uuid': '01HGWJRHD1AQSJ4807YYGBZ4R2'}
# では、現在の生徒の履修状況を確認します
# 西田 太郎さんの履修状況
# [{'join_lesson_uuid': '01HGWJRF730CW9SADHXHH8MHSN',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#                           'name': '数学',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'},
#  {'join_lesson_uuid': '01HGWJRFEG7A8QNME74MH3KTPZ',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#                           'name': '英語',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'},
#  {'join_lesson_uuid': '01HGWJRFN9DSYDYYE7WRWZPXG8',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#                           'name': '理科',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCG29TMYVY53YACKJBPM'},
#   'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'}]
#
# 松尾 雅人さんの履修状況
# [{'join_lesson_uuid': '01HGWJRFXH347Y217QHHCKJMG7',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#                           'name': '数学',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'},
#  {'join_lesson_uuid': '01HGWJRG83SAFQ8DXZXYH7HC8M',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#                           'name': '理科',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCG29TMYVY53YACKJBPM'},
#   'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#   'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'}]
#
# 山田 雅人さんの履修状況
# [{'join_lesson_uuid': '01HGWJRGJ40XBWJ2GR12587JET',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#                           'name': '英語',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#   'student_uuid': '01HGWJRBK3YD2C962EZ5893APC'},
#  {'join_lesson_uuid': '01HGWJRGVHP32PKWJ7RQXF9GF6',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#                           'name': '理科',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCG29TMYVY53YACKJBPM'},
#   'lesson_uuid': '01HGWJRDD1Q597Z7YVDEP2M2KG',
#   'student_uuid': '01HGWJRBK3YD2C962EZ5893APC'}]
#
# 中島 秀樹さんの履修状況
# [{'join_lesson_uuid': '01HGWJRH52THNQVMJCRHTNFVS2',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#                           'name': '数学',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'},
#  {'join_lesson_uuid': '01HGWJRHD1AQSJ4807YYGBZ4R2',
#   'lesson_join_lessons': {'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#                           'name': '英語',
#                           'status': 0,
#                           'teacher_uuid': '01HGWJRCA0F1DS3ZKZ9RGMD51K'},
#   'lesson_uuid': '01HGWJRD2JF8C8ZE62WA4697P0',
#   'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'}]
#
# 小林 雅人さんの履修状況
# []
#
# では、現在の生徒の出席状況を確認します
# 西田 太郎さんの出席状況
# []
#
# 松尾 雅人さんの出席状況
# []
#
# 山田 雅人さんの出席状況
# []
#
# 中島 秀樹さんの出席状況
# []
#
# 小林 雅人さんの出席状況
# []
#
# 授業が開始します
# 数学が開始します
# {'message': 'ok'}
# Aさんが出席します
# {'message': 'ok'}
# Bさんが出席します
# {'message': 'ok'}
# Dさんは出席しません
# 授業が終了します
# では、現在の生徒の出席状況を確認します
# 西田 太郎さんの出席状況
# [{'attendance_uuid': '01HGWJRP15SC4F4K4RQ1XK48S8',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': 1,
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'}]
#
# 松尾 雅人さんの出席状況
# [{'attendance_uuid': '01HGWJRP15WHSVB9ZKPS4AFYZC',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': 1,
#   'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'}]
#
# 山田 雅人さんの出席状況
# []
#
# 中島 秀樹さんの出席状況
# [{'attendance_uuid': '01HGWJRP15JC4QA3M6Q4E823E2',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': -1,
#   'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'}]
#
# 小林 雅人さんの出席状況
# []
#
# では、現在の授業の出席状況を確認します
# 数学の出席状況
# [{'attendance_uuid': '01HGWJRP15SC4F4K4RQ1XK48S8',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': 1,
#   'student_uuid': '01HGWJRB4ZKR1TPKASWVRCCSHH'},
#  {'attendance_uuid': '01HGWJRP15WHSVB9ZKPS4AFYZC',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': 1,
#   'student_uuid': '01HGWJRBBVVX7NNRCNFR9PDQFP'},
#  {'attendance_uuid': '01HGWJRP15JC4QA3M6Q4E823E2',
#   'lesson_uuid': '01HGWJRCSXZTR86C0Y1KPXBR85',
#   'status': -1,
#   'student_uuid': '01HGWJRBT2EY8NDE4ARNPTRDCH'}]
#
# 英語の出席状況
# []
#
# 理科の出席状況
# []
